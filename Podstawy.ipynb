# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
print("Jak masz na imię?")
imie = input()
print("Cześć", imie)
# Out:
# Jak masz na imię?
# Zuzanna
# Cześć Zuzanna

# %%
if 5 > 0:
    print("Pięć jest większe od zera")
print("Koniec programu")
# Out:
# Pięć jest większe od zera
# Koniec programu

# %%
x = 1
if x<2:
    print("Mało")
elif x<5:
    print("Średnio")
else:
     print("Dużo")
# Out:
# Mało

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
tablica = ["Alicja", "Bob", "Celina"]
for t in tablica:
    print("Hello, {}!".format(t))
# Out:
# Hello, Alicja!
# Hello, Bob!
# Hello, Celina!

# %%
tablica
# Out:
# ['Alicja', 'Bob', 'Celina']

# %%
collection = ("Dania","Belgia","Finlandia")
collection[0]
# Out:
# 'Dania'

# %%
collection[-2]
# Out:
# 'Belgia'

# %%
word = 'Uniwersytet'
word[2], word[-1]
# Out:
# ('i', 't')

# %%
lista = ['katedra','uniwersytet','instytut']
lista[1], lista[-3]
# Out:
# ('uniwersytet', 'katedra')

# %%
collection = ("Dania","Belgia","Finlandia")
collection[0:2]
# Out:
# ('Dania', 'Belgia')

# %%
collection[-2:]
# Out:
# ('Belgia', 'Finlandia')

# %%
l = list()
l.append('a')
l.append('b')
l
# Out:
# ['a', 'b']

# %%
word = 'Uniwersytet'
word[0:3]
# Out:
# 'Uni'

# %%
word[-5:-1]
# Out:
# 'syte'

# %%
lista = ['katedra','uniwersytet','instytut']
lista[:1]
# Out:
# ['katedra']

# %%
lista[-2:]
# Out:
# ['uniwersytet', 'instytut']

# %%
x = range(6)
x
# Out:
# range(0, 6)

# %%
x = [i for i in x]
x
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
y = [i*i for i in x]
y
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
z = map(lambda i: i*i, x)
z

# %%
list(z)
# Out:
# [0, 1, 4, 9, 16, 25]
